# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %% [markdown]
# # The COVID Tracking Project (CTP)(All states)

# %%
def get_ctp():
    return pd.read_csv('../datasets/ctp/ctp-all.csv')

# %%
ctp_df = get_ctp()
ctp_df
# Out:
#              date state dataQualityGrade    death  deathConfirmed  \
# 0      2021-02-06    AK                A    279.0             NaN
# 1      2021-02-06    AL                A   8513.0          6746.0
# 2      2021-02-06    AR               A+   5061.0          4043.0
# 3      2021-02-06    AS              NaN      0.0             NaN
# 4      2021-02-06    AZ               A+  14011.0         12451.0
# ...           ...   ...              ...      ...             ...
# 19144  2020-01-17    WA              NaN      NaN             NaN
# 19145  2020-01-16    WA              NaN      NaN             NaN
# 19146  2020-01-15    WA              NaN      NaN             NaN
# 19147  2020-01-14    WA              NaN      NaN             NaN
# 19148  2020-01-13    WA              NaN      NaN             NaN
#
#        deathIncrease  deathProbable  hospitalized  hospitalizedCumulative  \
# 0                  0            NaN        1219.0                  1219.0
# ...

# %%
for feature in ctp_df:
    print(feature)
# Out:
# date
# state
# dataQualityGrade
# death
# deathConfirmed
# deathIncrease
# deathProbable
# hospitalized
# hospitalizedCumulative
# hospitalizedCurrently
# hospitalizedIncrease
# inIcuCumulative
# inIcuCurrently
# negative
# negativeIncrease
# negativeTestsAntibody
# negativeTestsPeopleAntibody
# negativeTestsViral
# onVentilatorCumulative
# onVentilatorCurrently
# positive
# positiveCasesViral
# positiveIncrease
# positiveScore
# positiveTestsAntibody
# positiveTestsAntigen
# positiveTestsPeopleAntibody
# positiveTestsPeopleAntigen
# positiveTestsViral
# recovered
# totalTestEncountersViral
# totalTestEncountersViralIncrease
# totalTestResults
# totalTestResultsIncrease
# totalTestsAntibody
# totalTestsAntigen
# totalTestsPeopleAntibody
# totalTestsPeopleAntigen
# totalTestsPeopleViral
# totalTestsPeopleViralIncrease
# totalTestsViral
# totalTestsViralIncrease

# %%
profile = ProfileReport(ctp_df, title='The Covid Tracking Project', explorative=True)
profile.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Google Mobility Reports (US Regions)

# %%
def get_mobility():
    return pd.read_csv('../datasets/mobility/2020_US_Region_Mobility_Report.csv')
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 0                       US  United States          NaN            NaN
# 1                       US  United States          NaN            NaN
# 2                       US  United States          NaN            NaN
# 3                       US  United States          NaN            NaN
# 4                       US  United States          NaN            NaN
# ...                    ...            ...          ...            ...
# 892363                  US  United States      Wyoming  Weston County
# 892364                  US  United States      Wyoming  Weston County
# 892365                  US  United States      Wyoming  Weston County
# 892366                  US  United States      Wyoming  Weston County
# 892367                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code        date  \
# ...
