# %%
import pandas as pd

# %%
fl_df = pd.read_csv('exports/florida.csv')
fl_scaled_df = pd.read_csv('exports/florida-scaled.csv')

# %%
fl_df = fl_df.set_index('date')
fl_df
# Out:
#               death  deathIncrease  hospitalized  hospitalizedIncrease  \
# date
# 2020-03-21     12.0              2         158.0                   158
# 2020-03-22     13.0              1         185.0                    27
# 2020-03-23     14.0              1         217.0                    32
# 2020-03-24     18.0              4         259.0                    42
# 2020-03-25     22.0              4         316.0                    57
# ...             ...            ...           ...                   ...
# 2020-12-27  21514.0             77       62296.0                   178
# 2020-12-28  21613.0             99       62507.0                   211
# 2020-12-29  21718.0            105       62999.0                   492
# 2020-12-30  21857.0            139       63375.0                   376
# 2020-12-31  21990.0            133       63741.0                   366
#
#              positive  positiveIncrease   negative  negativeIncrease  \
# date
# ...

# %%
fl_scaled_df = fl_scaled_df.set_index('date')
fl_scaled_df
# Out:
#                death  deathIncrease  hospitalized  hospitalizedIncrease  \
# date
# 2020-03-21  0.000000       0.007220      0.000000              0.253612
# 2020-03-22  0.000046       0.003610      0.000425              0.043339
# 2020-03-23  0.000091       0.003610      0.000928              0.051364
# 2020-03-24  0.000273       0.014440      0.001588              0.067416
# 2020-03-25  0.000455       0.014440      0.002485              0.091493
# ...              ...            ...           ...                   ...
# 2020-12-27  0.978342       0.277978      0.977274              0.285714
# 2020-12-28  0.982846       0.357401      0.980592              0.338684
# 2020-12-29  0.987624       0.379061      0.988330              0.789727
# 2020-12-30  0.993948       0.501805      0.994244              0.603531
# 2020-12-31  1.000000       0.480144      1.000000              0.587480
#
#             positive  positiveIncrease  negative  negativeIncrease  \
# date
# ...

# %%
len(fl_scaled_df)
# Out:
# 286

# %% [markdown]
# # Splitting

# %%
train_split = round(0.70*len(fl_scaled_df))
train_split
# Out:
# 200

# %%
fl_train_df, fl_test_df = fl_scaled_df[:train_split], fl_scaled_df[train_split:]

# %%
# train
fl_train_df
# Out:
#                death  deathIncrease  hospitalized  hospitalizedIncrease  \
# date
# 2020-03-21  0.000000       0.007220      0.000000              0.253612
# 2020-03-22  0.000046       0.003610      0.000425              0.043339
# 2020-03-23  0.000091       0.003610      0.000928              0.051364
# 2020-03-24  0.000273       0.014440      0.001588              0.067416
# 2020-03-25  0.000455       0.014440      0.002485              0.091493
# ...              ...            ...           ...                   ...
# 2020-10-02  0.669670       0.400722      0.705110              0.272873
# 2020-10-03  0.672991       0.263538      0.707626              0.256822
# 2020-10-04  0.674902       0.151625      0.708633              0.102729
# 2020-10-05  0.676768       0.148014      0.709687              0.107544
# 2020-10-06  0.679452       0.212996      0.713414              0.380417
#
#             positive  positiveIncrease  negative  negativeIncrease  \
# date
# ...

# %%
# test
fl_test_df
# Out:
#                death  deathIncrease  hospitalized  hospitalizedIncrease  \
# date
# 2020-10-07  0.685777       0.501805      0.717472              0.414125
# 2020-10-08  0.693512       0.613718      0.721058              0.365971
# 2020-10-09  0.698881       0.425993      0.724140              0.314607
# 2020-10-10  0.698881       0.000000      0.724140              0.000000
# 2020-10-11  0.707071       0.649819      0.728056              0.399679
# ...              ...            ...           ...                   ...
# 2020-12-27  0.978342       0.277978      0.977274              0.285714
# 2020-12-28  0.982846       0.357401      0.980592              0.338684
# 2020-12-29  0.987624       0.379061      0.988330              0.789727
# 2020-12-30  0.993948       0.501805      0.994244              0.603531
# 2020-12-31  1.000000       0.480144      1.000000              0.587480
#
#             positive  positiveIncrease  negative  negativeIncrease  \
# date
# ...
